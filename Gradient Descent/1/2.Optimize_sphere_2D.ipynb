# %% [markdown]
# # 3D Sphere Function and Its Derivative
#
# The sphere function is defined as:
#
# $f(x) = x^2 + y^2$
#
#
# The derivative of the sphere function is:
#
# $df/dx = 2x$
#
# $df/dy = 2y$

# %%
def func(x, y):
    return x**2 + y**2

def gradient(x, y):
    dx = 2*x
    dy = 2*y
    return dx, dy

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm

xmin, xmax, xstep = -4.5, 4.5, .2
ymin, ymax, ystep = -4.5, 4.5, .2

x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep), np.arange(ymin, ymax + ystep, ystep))
z = func(x, y)

# 3D Surface Plot
fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d', elev=0, azim=-40)

ax.plot_surface(x, y, z, norm=LogNorm(), rstride=1, cstride=1, 
                edgecolor='none', alpha=.9, cmap=plt.cm.jet)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')

ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))

plt.show()

# %% [markdown]
# # Optimization Process

# %%
import random

# set (x,y) randomly
x = random.randint(-100, 100)
y = random.randint(-100, 100)
print(x, y)
x_scatter = [x]
y_scatter = [y]

# params
num_iterations = 50
lr = 0.1

# optimize
for _ in range(num_iterations):
    # compute the derivative at (x,y)
    dx, dy = gradient(x, y)
            
    # update
    x = x - lr*dx
    y = y - lr*dy
    x_scatter.append(x)
    y_scatter.append(y)
    
    print(x, y, func(x,y))
# Out:
# -23 -89
# -18.4 -71.2 5408.0
# -14.719999999999999 -56.96 3461.12
# -11.776 -45.568 2215.1168
# -9.4208 -36.4544 1417.674752
# -7.53664 -29.16352 907.31184128
# -6.029312 -23.330816 580.6795784191999
# -4.8234496 -18.6646528 371.63493018828797
# -3.85875968 -14.93172224 237.8463553205043
# -3.087007744 -11.945377791999999 152.22166740512273
# -2.4696061952 -9.556302233599999 97.42186713927853
# -1.9756849561599998 -7.6450417868799985 62.349994969138265
# -1.5805479649279999 -6.116033429503998 39.903996780248484
# -1.2644383719424 -4.892826743603199 25.53855793935903
# -1.01155069755392 -3.9142613948825593 16.34467708118978
# -0.8092405580431359 -3.1314091159060475 10.46059333196146
# -0.6473924464345087 -2.505127292724838 6.694779732455335
# -0.5179139571476069 -2.0041018341798704 4.284659028771414
# -0.41433116571808554 -1.6032814673438964 2.7421817784137055
# -0.3314649325744684 -1.282625173875117 1.7549963381847713
# -0.2651719460595747 -1.0261001391000937 1.1231976564382535
# -0.21213755684765978 -0.820880111280075 0.7188465001204823
# -0.16971004547812782 -0.65670408902406 0.4600617600771087
# -0.13576803638250226 -0.525363271219248 0.29443952644934956
# -0.1086144291060018 -0.4202906169753984 0.18844129692758374
# -0.08689154328480145 -0.3362324935803187 0.12060243003365358
# -0.06951323462784116 -0.26898599486425495 0.07718555522153829
# -0.05561058770227293 -0.21518879589140397 0.049398755341784506
# -0.044488470161818346 -0.17215103671312318 0.031615203418742084
# -0.035590776129454674 -0.13772082937049854 0.020233730187994934
# -0.02847262090356374 -0.11017666349639883 0.012949587320316758
# -0.022778096722850992 -0.08814133079711907 0.008287735885002725
# -0.018222477378280793 -0.07051306463769526 0.005304150966401746
# -0.014577981902624635 -0.056410451710156205 0.0033946566184971166
# -0.011662385522099708 -0.04512836136812497 0.002172580235838155
# -0.009329908417679767 -0.03610268909449997 0.0013904513509364188
# -0.0074639267341438135 -0.028882151275599975 0.000889888864599308
# -0.005971141387315051 -0.02310572102047998 0.0005695288733435571
# -0.0047769131098520405 -0.018484576816383984 0.0003644984789398765
# -0.0038215304878816323 -0.014787661453107188 0.000233279026521521
# -0.0030572243903053057 -0.01183012916248575 0.00014929857697377347
# -0.0024457795122442448 -0.0094641033299886 9.5551089263215e-05
# -0.001956623609795396 -0.00757128266399088 6.115269712845761e-05
# -0.0015652988878363167 -0.006057026131192704 3.9137726162212875e-05
# -0.0012522391102690535 -0.004845620904954164 2.504814474381624e-05
# -0.0010017912882152428 -0.0038764967239633312 1.6030812636042395e-05
# -0.0008014330305721942 -0.003101197379170665 1.0259720087067132e-05
# -0.0006411464244577554 -0.002480957903336532 6.566220855722965e-06
# -0.0005129171395662043 -0.0019847663226692258 4.202381347662698e-06
# -0.0004103337116529634 -0.0015878130581353806 2.6895240625041266e-06
# -0.00032826696932237076 -0.0012702504465083044 1.721295400002641e-06
